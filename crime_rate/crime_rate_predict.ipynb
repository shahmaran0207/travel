# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split

# %%
cr_df = pd.read_excel('crime_rate.xlsx')
po_df = pd.read_excel('population.xlsx')
police_df = pd.read_excel('police.xlsx')

# %%
# 도시별 범죄율 구분
gangwon_cr =cr_df[cr_df['시도구분'] == '강원도']
gunggi_cr =cr_df[cr_df['시도구분'] == '경기도']
gungnam_cr =cr_df[cr_df['시도구분'] == '경상남도']
gungbuk_cr =cr_df[cr_df['시도구분'] == '경상북도']
gwangju_cr =cr_df[cr_df['시도구분'] == '광주광역시']
daegu_cr =cr_df[cr_df['시도구분'] == '대구광역시']
daejeon_cr =cr_df[cr_df['시도구분'] == '대전광역시']
busan_cr =cr_df[cr_df['시도구분'] == '부산광역시']
ulsan_cr =cr_df[cr_df['시도구분'] == '울산광역시']
seoul_cr =cr_df[cr_df['시도구분'] == '서울특별시']
incheon_cr =cr_df[cr_df['시도구분'] == '인천광역시']
jeonnam_cr =cr_df[cr_df['시도구분'] == '전라남도']
jeonbuk_cr =cr_df[cr_df['시도구분'] == '전라북도']
jeju_cr =cr_df[cr_df['시도구분'] == '제주특별자치도']
chungnam_cr =cr_df[cr_df['시도구분'] == '충청남도']
chungbuk_cr =cr_df[cr_df['시도구분'] == '충청북도']

# 도시별 인구 구분
gangwon_po =po_df[po_df['시도구분'] == '강원도']
gunggi_po =po_df[po_df['시도구분'] == '경기도']
gungnam_po =po_df[po_df['시도구분'] == '경상남도']
gungbuk_po =po_df[po_df['시도구분'] == '경상북도']
gwangju_po =po_df[po_df['시도구분'] == '광주광역시']
daegu_po =po_df[po_df['시도구분'] == '대구광역시']
daejeon_po =po_df[po_df['시도구분'] == '대전광역시']
busan_po =po_df[po_df['시도구분'] == '부산광역시']
ulsan_po =po_df[po_df['시도구분'] == '울산광역시']
seoul_po =po_df[po_df['시도구분'] == '서울특별시']
incheon_po =po_df[po_df['시도구분'] == '인천광역시']
jeonnam_po =po_df[po_df['시도구분'] == '전라남도']
jeonbuk_po =po_df[po_df['시도구분'] == '전라북도']
jeju_po =po_df[po_df['시도구분'] == '제주특별자치도']
chungnam_po =po_df[po_df['시도구분'] == '충청남도']
chungbuk_po =po_df[po_df['시도구분'] == '충청북도']

# 도시별 경찰수 구분
gangwon_police =police_df[police_df['시도구분'] == '강원도']
gunggi_police =police_df[police_df['시도구분'] == '경기도']
gungnam_police =police_df[police_df['시도구분'] == '경상남도']
gungbuk_police =police_df[police_df['시도구분'] == '경상북도']
gwangju_police =police_df[police_df['시도구분'] == '광주광역시']
daegu_police =police_df[police_df['시도구분'] == '대구광역시']
daejeon_police =police_df[police_df['시도구분'] == '대전광역시']
busan_police =police_df[police_df['시도구분'] == '부산광역시']
ulsan_police =police_df[police_df['시도구분'] == '울산광역시']
seoul_police =police_df[police_df['시도구분'] == '서울특별시']
incheon_police =police_df[police_df['시도구분'] == '인천광역시']
jeonnam_police =police_df[police_df['시도구분'] == '전라남도']
jeonbuk_police =police_df[police_df['시도구분'] == '전라북도']
jeju_police =police_df[police_df['시도구분'] == '제주특별자치도']
chungnam_police =police_df[police_df['시도구분'] == '충청남도']
chungbuk_police =police_df[police_df['시도구분'] == '충청북도']

# %%
#지역별 범죄율 데이터 전처리
gangwon_cr=gangwon_cr.transpose()
gangwon_cr=gangwon_cr.drop(gangwon_cr.index[0])
gangwon_cr.columns=['강원도']

gunggi_cr=gunggi_cr.transpose()
gunggi_cr=gunggi_cr.drop(gunggi_cr.index[0])
gunggi_cr.columns=['경기도']

gungnam_cr=gungnam_cr.transpose()
gungnam_cr=gungnam_cr.drop(gungnam_cr.index[0])
gungnam_cr.columns=['경상남도']

gungbuk_cr=gungbuk_cr.transpose()
gungbuk_cr=gungbuk_cr.drop(gungbuk_cr.index[0])
gungbuk_cr.columns=['경상북도']

gwangju_cr=gwangju_cr.transpose()
gwangju_cr=gwangju_cr.drop(gwangju_cr.index[0])
gwangju_cr.columns=['광주광역시']

daegu_cr=daegu_cr.transpose()
daegu_cr=daegu_cr.drop(daegu_cr.index[0])
daegu_cr.columns=['대구광역시']

daejeon_cr=daejeon_cr.transpose()
daejeon_cr=daejeon_cr.drop(daejeon_cr.index[0])
daejeon_cr.columns=['대전광역시']

busan_cr=busan_cr.transpose()
busan_cr=busan_cr.drop(busan_cr.index[0])
busan_cr.columns=['부산광역시']

ulsan_cr=ulsan_cr.transpose()
ulsan_cr=ulsan_cr.drop(ulsan_cr.index[0])
ulsan_cr.columns=['울산광역시']

seoul_cr=seoul_cr.transpose()
seoul_cr=seoul_cr.drop(seoul_cr.index[0])
seoul_cr.columns=['서울특별시']

incheon_cr=incheon_cr.transpose()
incheon_cr=incheon_cr.drop(incheon_cr.index[0])
incheon_cr.columns=['인천광역시']

jeonnam_cr=jeonnam_cr.transpose()
jeonnam_cr=jeonnam_cr.drop(jeonnam_cr.index[0])
jeonnam_cr.columns=['전라남도']

jeonbuk_cr=jeonbuk_cr.transpose()
jeonbuk_cr=jeonbuk_cr.drop(jeonbuk_cr.index[0])
jeonbuk_cr.columns=['전라북도']

jeju_cr=jeju_cr.transpose()
jeju_cr=jeju_cr.drop(jeju_cr.index[0])
jeju_cr.columns=['제주특별자치도']

chungnam_cr=chungnam_cr.transpose()
chungnam_cr=chungnam_cr.drop(chungnam_cr.index[0])
chungnam_cr.columns=['충청남도']

chungbuk_cr=chungbuk_cr.transpose()
chungbuk_cr=chungbuk_cr.drop(chungbuk_cr.index[0])
chungbuk_cr.columns=['충청북도']

# %%
#지역별 인구 데이터 전처리
gangwon_po=gangwon_po.transpose()
gangwon_po=gangwon_po.drop(gangwon_po.index[0])
gangwon_po.columns=['강원도']

gunggi_po=gunggi_po.transpose()
gunggi_po=gunggi_po.drop(gunggi_po.index[0])
gunggi_po.columns=['경기도']

gungnam_po=gungnam_po.transpose()
gungnam_po=gungnam_po.drop(gungnam_po.index[0])
gungnam_po.columns=['경상남도']

gungbuk_po=gungbuk_po.transpose()
gungbuk_po=gungbuk_po.drop(gungbuk_po.index[0])
gungbuk_po.columns=['경상북도']

gwangju_po=gwangju_po.transpose()
gwangju_po=gwangju_po.drop(gwangju_po.index[0])
gwangju_po.columns=['광주광역시']

daegu_po=daegu_po.transpose()
daegu_po=daegu_po.drop(daegu_po.index[0])
daegu_po.columns=['대구광역시']

daejeon_po=daejeon_po.transpose()
daejeon_po=daejeon_po.drop(daejeon_po.index[0])
daejeon_po.columns=['대전광역시']

busan_po=busan_po.transpose()
busan_po=busan_po.drop(busan_po.index[0])
busan_po.columns=['부산광역시']

ulsan_po=ulsan_po.transpose()
ulsan_po=ulsan_po.drop(ulsan_po.index[0])
ulsan_po.columns=['울산광역시']

seoul_po=seoul_po.transpose()
seoul_po=seoul_po.drop(seoul_po.index[0])
seoul_po.columns=['서울특별시']

incheon_po=incheon_po.transpose()
incheon_po=incheon_po.drop(incheon_po.index[0])
incheon_po.columns=['인천광역시']

jeonnam_po=jeonnam_po.transpose()
jeonnam_po=jeonnam_po.drop(jeonnam_po.index[0])
jeonnam_po.columns=['전라남도']

jeonbuk_po=jeonbuk_po.transpose()
jeonbuk_po=jeonbuk_po.drop(jeonbuk_po.index[0])
jeonbuk_po.columns=['전라북도']

jeju_po=jeju_po.transpose()
jeju_po=jeju_po.drop(jeju_po.index[0])
jeju_po.columns=['제주특별자치도']

chungnam_po=chungnam_po.transpose()
chungnam_po=chungnam_po.drop(chungnam_po.index[0])
chungnam_po.columns=['충청남도']

chungbuk_po=chungbuk_po.transpose()
chungbuk_po=chungbuk_po.drop(chungbuk_po.index[0])
chungbuk_po.columns=['충청북도']

# %%
#지역별 경찰수 데이터 전처리
gangwon_police=gangwon_police.transpose()
gangwon_police=gangwon_police.drop(gangwon_police.index[0])
gangwon_police.columns=['강원도']

gunggi_police=gunggi_police.transpose()
gunggi_police=gunggi_police.drop(gunggi_police.index[0])
gunggi_police.columns=['경기도']

gungnam_police=gungnam_police.transpose()
gungnam_police=gungnam_police.drop(gungnam_police.index[0])
gungnam_police.columns=['경상남도']

gungbuk_police=gungbuk_police.transpose()
gungbuk_police=gungbuk_police.drop(gungbuk_police.index[0])
gungbuk_police.columns=['경상북도']

gwangju_police=gwangju_police.transpose()
